# %%
import time
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/Colab_Notebooks/ICML2021/diabetes/data/diabetes.data_train_5.7', header = None, sep = ' ')
X = data.to_numpy()
y = X[:,2]
X = X[:,0:2]

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(X[:,0], X[:,1], c=y, alpha=.8)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

plt.show()

# %% [markdown]
# Sin Escalar

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(X[:,0], X[:,1], c=y, alpha=.8)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

plt.show()

# %%
data = pd.read_csv('/content/drive/My Drive/Colab_Notebooks/ICML2021/diabetes/data/diabetes.data_test_5.7', header = None, sep = ' ')
X_test = data.to_numpy()
y = X_test[:,2]
X_test = X_test[:,0:2]

# %%
X_test = scaler.transform(X_test)

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(X_test[:,0], X_test[:,1], c=y, alpha=.8)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

plt.show()

# %% [markdown]
# Sin Esaclar:

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(X_test[:,0], X_test[:,1], c=y, alpha=.8)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

plt.show()
